# %% [markdown]
# # Summary_Day17.ipynb
# ## 17강 자연어처리 NLP 종합실습 정리 안내
#
# 이번 17강은 실행 환경에 따라 두 개의 실습 파일로 나누었다.
#
# ```text
# 인터넷 가능 → Summary_Day17_online_student_note_da.ipynb
# 인터넷 불가 → Summary_Day17_offline_student_note_da.ipynb
# ```
#
# - 인터넷 가능 버전은 강의 원본 흐름처럼 Hugging Face IMDb dataset, BiLSTM, DistilBERT를 사용한다.
# - 인터넷 불가 버전은 직접 만든 문장 데이터로 tokenizer, vocab, padding, LSTM/BiLSTM 구조를 연습한다.
# - 실제 강의 기준 복습은 online 버전을 중심으로 보면 된다.

# %%
print("17강 자연어처리 NLP 종합실습 정리 파일")
print("1. Summary_Day17_online_student_note_da.ipynb")
print("2. Summary_Day17_offline_student_note_da.ipynb")
print("3. README_AI_17차시_정리_student_note_da.md")
