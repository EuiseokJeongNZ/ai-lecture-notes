# %% [markdown]
# # Summary_Day15.ipynb
# ## 15강 사용자 데이터 분류 정리 안내
#
# 이번 15강은 실행 환경에 따라 두 개의 실습 파일로 나누었다.
#
# ```text
# 인터넷 가능 → Summary_Day15_online_student_note_da.ipynb
# 인터넷 불가 → Summary_Day15_offline_student_note_da.ipynb
# ```
#
# - 인터넷 가능 버전은 강의 원본 흐름처럼 `hymenoptera_data`, `dog_wolf`, CIFAR-10, pretrained VGG19-BN/ResNet18을 사용한다.
# - 인터넷 불가 버전은 직접 생성한 이미지 폴더와 작은 CNN, `weights=None` ResNet18 구조로 연습한다.
# - 실제 강의 기준 복습은 online 버전을 중심으로 보면 된다.

# %%
print("15강 사용자 데이터 분류 정리 파일")
print("1. Summary_Day15_online_student_note_da.ipynb")
print("2. Summary_Day15_offline_student_note_da.ipynb")
print("3. README_AI_15차시_정리_student_note_da.md")
