# %% [markdown]
# # Summary_Day12.ipynb
# ## 12강 튜닝/최적화 및 과적합 대응 정리 안내
#
# 이번 12강은 업로드한 **튜닝/최적화 및 과적합(Overfitting)** 강의 기준으로 다시 정리했다.
#
# 실행 환경에 따라 두 개의 실습 파일로 나누었다.
#
# ```text
# 인터넷 가능 → Summary_Day12_tuning_online_student_note_da.ipynb
# 인터넷 불가 → Summary_Day12_tuning_offline_student_note_da.ipynb
# ```
#
# - 인터넷 가능 버전은 CIFAR-10을 `torchvision.datasets`로 다운로드한다.
# - 인터넷 불가 버전은 합성 CIFAR-10식 데이터를 직접 만들어 실행한다.
# - 두 버전 모두 Optimizer, Dropout, BatchNorm, Data Augmentation, train/eval mode, Softmax 오답 분석 흐름을 따른다.

# %%
print("12강 튜닝/최적화 및 과적합 대응 정리 파일")
print("1. Summary_Day12_tuning_online_student_note_da.ipynb")
print("2. Summary_Day12_tuning_offline_student_note_da.ipynb")
print("3. README_AI_12차시_튜닝_정리_student_note_da.md")
