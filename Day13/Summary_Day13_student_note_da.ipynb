# %% [markdown]
# # Summary_Day13.ipynb
# ## 13강 사전학습 모델 활용 1 정리 안내
#
# 이번 13강은 실행 환경에 따라 두 개의 실습 파일로 나누었다.
#
# ```text
# 인터넷 가능 → Summary_Day13_online_student_note_da.ipynb
# 인터넷 불가 → Summary_Day13_offline_student_note_da.ipynb
# ```
#
# - 인터넷 가능 버전은 CIFAR-10 데이터와 ImageNet 사전학습 가중치를 다운로드한다.
# - 인터넷 불가 버전은 FakeData와 `weights=None`으로 구조 수정 흐름을 연습한다.
# - 두 버전 모두 ResNet18, VGG19-BN, MobileNetV2의 마지막 layer 교체, fine-tuning, transfer learning 구조를 정리한다.

# %%
print("13강 사전학습 모델 활용 1 정리 파일")
print("1. Summary_Day13_online_student_note_da.ipynb")
print("2. Summary_Day13_offline_student_note_da.ipynb")
print("3. README_AI_13차시_정리_student_note_da.md")
