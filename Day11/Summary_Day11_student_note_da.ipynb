# %% [markdown]
# # Summary_Day11.ipynb
# ## 11강 CNN 기반 이미지 분류 정리 안내
#
# 이번 11강은 실행 환경에 따라 두 개의 실습 파일로 나누었다.
#
# ```text
# 인터넷 가능 → Summary_Day11_online_student_note_da.ipynb
# 인터넷 불가 → Summary_Day11_offline_student_note_da.ipynb
# ```
#
# - 인터넷 가능 버전은 MNIST와 CIFAR-10을 `torchvision.datasets`로 다운로드한다.
# - 인터넷 불가 버전은 합성 이미지 데이터를 직접 만들어 CNN 구조를 실행한다.
# - 두 버전 모두 강의 핵심인 `Conv2d → ReLU → MaxPool2d → Flatten → Linear` 흐름을 정리한다.

# %%
print("11강 CNN 기반 이미지 분류 정리 파일")
print("1. Summary_Day11_online_student_note_da.ipynb")
print("2. Summary_Day11_offline_student_note_da.ipynb")
print("3. README_AI_11차시_정리_student_note_da.md")
